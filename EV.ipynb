# %% [markdown]
# # Table of Contents
#
# [Data Description](#Data-Description)\
# [Action Points](#Action-Points)\
# [Install Libraries](#Install-Libraries)\
# [Import Libraries](#Import-Libraries)\
# [Load/Read the file](#Load/Read-the-file)\
# [Drop Unnecessary Columns](#Drop-Unnecessary-Columns)\
# [Drop Duplicates](#Drop-Duplicates)\
# [Handling Missing Data](#Handling-Missing-Data)\
# [Unique Value in each column](#Unique-Value-in-each-column)\
# [Create a New Column](#Create-a-New-Column)\
# [Check Correlation](#Check-Correlation)\
# [Which counties have the highest number of electric vehicles (EVs)?](#1.-Which-counties-have-the-highest-number-of-electric-vehicles-(EVs)?)\
# [Which cities have the highest number of electric vehicles (EVs)?](#2.-Which-cities-have-the-highest-number-of-electric-vehicles-(EVs)?)\
# [Who are the top 10 EV manufacturers?](#3.-Who-are-the-top-10-EV-manufacturers?)\
# [What are the top 10 EV models?](#4.-What-are-the-top-10-EV-models?)\
# [Distribution of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) in percentage](#5.-Distribution-of-Battery-Electric-Vehicles-(BEVs)-and-Plug-in-Hybrid-Electric-Vehicles-(PHEVs)-in-percentage)\
# [Trend of EV sales over the years](#6.-Trend-of-EV-sales-over-the-years)\
# [Distribution of Clean Alternative Fuel Vehicles (CAFVs)](#7.-Distribution-of-Clean-Alternative-Fuel-Vehicles-(CAFVs))\
# [Average range of different makes](#8.-Average-range-of-different-makes)\
# [Top 10 makes by average range in percentage](#9.-Top-10-makes-by-average-range-in-percentage)\
# [Top 10 makes by average range](#10.-Top-10-makes-by-average-range)\
# [Top 10 makes with the highest number of vehicles in the top 10 counties](#11.-Top-10-makes-with-the-highest-number-of-vehicles-in-the-top-10-counties)\
# [Top 10 models with the highest number of vehicles in the top 10 counties](#12.-Top-10-models-with-the-highest-number-of-vehicles-in-the-top-10-counties)\
# [Top 10 makes with the highest number of vehicles in the top 10 cities](#13.-Top-10-makes-with-the-highest-number-of-vehicles-in-the-top-10-cities)\
# [Top 10 models with the highest number of vehicles in the top 10 cities](#14.-Top-10-models-with-the-highest-number-of-vehicles-in-the-top-10-cities)\
# [Top models of the top 1 make by count](#15.-Top-models-of-the-top-1-make-by-count)\
# [Tesla Models Electric Range](#16.-Tesla-Models-Electric-Range)

# %% [markdown]
# # Data Description
#
# 1. VIN (1-10): The first 10 characters of the Vehicle Identification Number.
# 2.    County: The county where the vehicle is registered.
# 3.    City: The city where the vehicle is registered.
# 4.    State: The state where the vehicle is registered (all values are likely "WA" for Washington State).
# 5.    Postal Code: The postal code corresponding to the vehicle’s registration location.
# 6.    Model Year: The year the vehicle was manufactured.
# 7.    Make: The manufacturer of the vehicle (e.g., Tesla, Chevrolet).
# 8.    Model: The model name of the vehicle (e.g., Model 3, Volt).
# 9.    Electric Vehicle Type: Indicates whether the vehicle is a Battery Electric Vehicle (BEV) or a Plug-in Hybrid Electric Vehicle (PHEV).
# 10.   Clean Alternative Fuel Vehicle (CAFV) Eligibility: Indicates whether the vehicle is eligible for a clean alternative fuel vehicle program.
# 11.   Electric Range: The range (in miles) the vehicle can travel on electric power alone.
# 12.   Base MSRP: The manufacturer’s suggested retail price for the base model of the vehicle.
# 13.   Legislative District: The legislative district where the vehicle is registered.
# 14.   DOL Vehicle ID: A unique identifier assigned by the Department of Licensing (DOL).
# 15.   Vehicle Location: Geographic coordinates (longitude and latitude) of the vehicle’s registration.
# 16.   Electric Utility: The electric utility company serving the area where the vehicle is registered.
# 17.   2020 Census Tract: The 2020 Census Tract corresponding to the vehicle’s registration location.

# %% [markdown]
# # Action Points

# %% [markdown]
# 1. Which counties have the highest number of electric vehicles (EVs)?
# 2. Which cities have the highest number of electric vehicles (EVs)?
# 3. Who are the top 10 EV manufacturers?
# 4. What are the top 10 EV models?
# 5. Distribution of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) in counts?
# 6. Distribution of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) in percentage?
# 5. What is the count and percentage distribution of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs)?
# 6. What is the trend of EV sales over the years?
# 7. What is the count and percentage distribution of Clean Alternative Fuel Vehicles (CAFVs)?
# 8. What is the average range of different makes?
# 9. what are the top 10 average range by makes in percentage?
# 10. what are the top 10 makes by average range in percentage?
# 11. Which are the top 10 makes with the highest number of vehicles  in the top 10 counties?
# 12. Which are the top 10 models with the highest number of vehicles  in the top 10 counties?
# 13. Which are the top 10 makes with the highest number of vehicles  in the top 10 cities?
# 14. Which are the top 10 models with the highest number of vehicles  in the top 10 cities?
# 15. What are the top models of the top 1 make by sales?
# 16. What are the Tesla Models Electric Range?

# %% [markdown]
# # Install Libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotib
# !pip install plotly

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Load/Read the file

# %%
df = pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
df.head()
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  1C4RJXN66R  Snohomish       Everett    WA      98204.0        2024
# 1  KNDJX3AEXG       King        Renton    WA      98058.0        2016
# 2  5YJ3E1EA3L       King       Seattle    WA      98125.0        2020
# 3  1G1RC6S5XH     Kitsap  Port Orchard    WA      98367.0        2017
# 4  5UXTA6C09P  Snohomish        Monroe    WA      98272.0        2023
#
#         Make     Model                   Electric Vehicle Type  \
# 0       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        KIA      SOUL          Battery Electric Vehicle (BEV)
# 2      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 3  CHEVROLET      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 4        BMW        X5  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range            21.0
# ...

# %%
df.shape
# Out:
# (194232, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194232 entries, 0 to 194231
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         194232 non-null  object
#  1   County                                             194223 non-null  object
#  2   City                                               194223 non-null  object
#  3   State                                              194232 non-null  object
#  4   Postal Code                                        194223 non-null  float64
#  5   Model Year                                         194232 non-null  int64
#  6   Make                                               194232 non-null  object
#  7   Model                                              194232 non-null  object
# ...

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  194223.000000  194232.000000   194230.000000  194230.000000
# mean    98175.800678    2020.781807       54.835458     978.730732
# std      2435.345863       2.999041       89.614355    7988.719011
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98372.000000    2023.000000       68.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         193800.000000    1.942320e+05       1.942230e+05
# mean              29.009954    2.248923e+08       5.297532e+10
# std               14.901335    7.357830e+07       1.607770e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
print(df.columns)
print(pd.DataFrame(df.columns , columns =['new']))
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')
#                                                   new
# 0                                          VIN (1-10)
# 1                                              County
# 2                                                City
# 3                                               State
# 4                                         Postal Code
# 5                                          Model Year
# 6                                                Make
# 7                                               Model
# 8                               Electric Vehicle Type
# 9   Clean Alternative Fuel Vehicle (CAFV) Eligibility
# ...

# %% [markdown]
# # Drop Unnecessary Columns

# %%
df.drop(columns=['Legislative District', '2020 Census Tract', 'DOL Vehicle ID' ] , inplace = True)
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Vehicle Location', 'Electric Utility'],
#       dtype='object')

# %% [markdown]
# # Drop Duplicates

# %%
df.duplicated().sum()
# Out:
# 50161

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (144071, 14)

# %% [markdown]
# # Handling Missing Data

# %%
df.isnull().sum().sum()
# Out:
# 53

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                            0
# County                                                9
# City                                                  9
# State                                                 0
# Postal Code                                           9
# Model Year                                            0
# Make                                                  0
# Model                                                 0
# Electric Vehicle Type                                 0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     0
# Electric Range                                        2
# Base MSRP                                             2
# Vehicle Location                                     13
# Electric Utility                                      9
# dtype: int64

# %%
# Percentage of missing Values

# %%
Missing_values_percentage = (df.isnull().sum() / len(df) )*100
Missing_values_percentage = Missing_values_percentage.sort_values(ascending=False)
Missing_values_percentage
# Out:
# Vehicle Location                                     0.009023
# County                                               0.006247
# City                                                 0.006247
# Postal Code                                          0.006247
# Electric Utility                                     0.006247
# Electric Range                                       0.001388
# Base MSRP                                            0.001388
# VIN (1-10)                                           0.000000
# State                                                0.000000
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# dtype: float64

# %%
# Show Missing/Null Values in plot
Missing_values_percentage.plot(kind='barh') # barh (horizontal bar)
# Out:
# <Axes: >

# %%
# Show Missing/Null Values in heatmap 
sns.heatmap(df.isnull() , yticklabels=False ,cmap='viridis') #,cbar=False
# Out:
# <Axes: >

# %%
#Impute the Null Values
df['County'] = df['County'].fillna('Unknown')
df['City'] = df['City'].fillna('Unknown')
df['Postal Code'] = df['Postal Code'].fillna(0)
df['Electric Range'] = df['Electric Range'].fillna(0)
df['Base MSRP'] = df['Base MSRP'].fillna(0)
df['Vehicle Location'] = df['Vehicle Location'].fillna('Unknown')
df['Electric Utility'] = df['Electric Utility'].fillna('Unknown')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Unique Value im each column

# %%
# Display the unique values in each column
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values out of {df[col].count()}")
# Out:
# VIN (1-10): 11695 unique values out of 144071
# County: 199 unique values out of 144071
# City: 757 unique values out of 144071
# State: 46 unique values out of 144071
# Postal Code: 906 unique values out of 144071
# Model Year: 22 unique values out of 144071
# Make: 42 unique values out of 144071
# Model: 151 unique values out of 144071
# Electric Vehicle Type: 2 unique values out of 144071
# Clean Alternative Fuel Vehicle (CAFV) Eligibility: 3 unique values out of 144071
# Electric Range: 104 unique values out of 144071
# Base MSRP: 31 unique values out of 144071
# Vehicle Location: 905 unique values out of 144071
# Electric Utility: 77 unique values out of 144071

# %% [markdown]
# # Create a New Column

# %%
df['Make_Model'] =df['Make'] + "-"+ df['Model']

# %% [markdown]
# # Check Correlation

# %%
numeric_df = df.select_dtypes(include=[np.number])
corr_matrix = numeric_df.corr()
styled_corr = corr_matrix.style.background_gradient(cmap='cividis')
styled_corr
# Out:
# <style type="text/css">
# #T_acb44_row0_col0, #T_acb44_row1_col1, #T_acb44_row2_col2, #T_acb44_row3_col3 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_acb44_row0_col1, #T_acb44_row0_col2 {
#   background-color: #535a6d;
#   color: #f1f1f1;
# }
# #T_acb44_row0_col3 {
#   background-color: #32436d;
#   color: #f1f1f1;
# }
# #T_acb44_row1_col0 {
#   background-color: #00234f;
#   color: #f1f1f1;
# }
# #T_acb44_row1_col2, #T_acb44_row1_col3, #T_acb44_row2_col0, #T_acb44_row2_col1, #T_acb44_row3_col0 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# #T_acb44_row2_col3 {
#   background-color: #4d556c;
#   color: #f1f1f1;
# }
# #T_acb44_row3_col1 {
#   background-color: #243c6e;
#   color: #f1f1f1;
# }
# #T_acb44_row3_col2 {
#   background-color: #656870;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_acb44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acb44_level0_col0" class="col_heading level0 col0" >Postal Code</th>
# ...

# %% [markdown]
# # 1. Which counties have the highest number of electric vehicles (EVs)?

# %%
county_counts = df['County'].value_counts().head(10)
print(county_counts)
print(county_counts.index)
print(county_counts.values)
# Out:
# County
# King         66098
# Snohomish    16254
# Pierce       13354
# Clark         9402
# Thurston      5659
# Kitsap        5462
# Spokane       4723
# Whatcom       3900
# Benton        2103
# Skagit        1919
# Name: count, dtype: int64
# Index(['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 'Spokane',
#        'Whatcom', 'Benton', 'Skagit'],
#       dtype='object', name='County')
# [66098 16254 13354  9402  5659  5462  4723  3900  2103  1919]

# %%
plt.figure(figsize=(12,6))
sns.barplot( x=county_counts.index , y= county_counts.values )
plt.title('Top Counties by Number of Electric Vehicles (EVs)')
plt.xlabel('County')
plt.ylabel('Count')
plt.xticks(rotation = 45)
# Increase the range of the y-axis to add some space above the highest bar
max_count_of_county =df['County'].value_counts().max()
plt.ylim(0 , max_count_of_county * 1.15)
# Display the count above each bar
for index, value  in enumerate(county_counts.values):
    plt.text(index,  value , f'{value:,}' ,ha='center' ,  va='bottom')
plt.show()

# %% [markdown]
# # 2. Which cities have the highest number of electric vehicles (EVs)?

# %%
city_counts = df['City'].value_counts().head(10)
print(city_counts)
print(city_counts.index)
print(city_counts.values)
# Out:
# City
# Seattle      23421
# Vancouver     5681
# Bellevue      5596
# Tacoma        3664
# Olympia       3553
# Bothell       3499
# Renton        3420
# Redmond       3370
# Kirkland      3252
# Sammamish     3072
# Name: count, dtype: int64
# Index(['Seattle', 'Vancouver', 'Bellevue', 'Tacoma', 'Olympia', 'Bothell',
#        'Renton', 'Redmond', 'Kirkland', 'Sammamish'],
#       dtype='object', name='City')
# [23421  5681  5596  3664  3553  3499  3420  3370  3252  3072]

# %%
plt.figure(figsize=(12,6))
sns.barplot( x=city_counts.index , y= city_counts.values )
plt.title('"Top Cities by Number of Electric Vehicles (EVs)"')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation = 45)
# Increase the range of the y-axis to add some space above the highest bar
max_count_of_city =df['City'].value_counts().max()
plt.ylim(0 , max_count_of_city * 1.15)
# Display the count above each bar
for index, value  in enumerate(city_counts.values):
    plt.text(index,  value , f'{value:,}' ,ha='center' ,  va='bottom')
plt.show()

# %% [markdown]
# # 3. Who are the top 10 EV manufacturers?

# %%
top_10_maker = df['Make'].value_counts().nlargest(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_10_maker.index , y=top_10_maker.values)
plt.title("Top 10 Electric Vehicle (EV) Manufacturers")
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # 4. What are the top 10 EV models?

# %%
top_10_model = df['Model'].value_counts().nlargest(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_10_model.index , y=top_10_model.values)
plt.title("Top 10 Electric Vehicle (EV) Models")
plt.xlabel('Model')
plt.ylabel('Count')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # 5. What is the count and percentage distribution of Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs)?

# %%
ev_type_counts = df['Electric Vehicle Type'].value_counts()
print(ev_type_counts)
print(ev_type_counts.values)
print(ev_type_counts.index)
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            106808
# Plug-in Hybrid Electric Vehicle (PHEV)     37263
# Name: count, dtype: int64
# [106808  37263]
# Index(['Battery Electric Vehicle (BEV)', 'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype='object', name='Electric Vehicle Type')

# %%
plt.figure(figsize=(8,5))
sns.barplot( x= ev_type_counts.index ,  y=ev_type_counts.values)
plt.title("Distribution of Electric Vehicale Type")
plt.xlabel('Electric Vehical Type')
plt.ylabel('Count')
plt.xticks(rotation = 35)
# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.grid(True)
# Extending the y-axis limit by 10% beyond the maximum value
max_value = df['Electric Vehicle Type'].value_counts().max()
plt.ylim(0, max_value * 1.1)
# Display the count above each bar
for index, value in enumerate(ev_type_counts.values):
    plt.text(index, value, f'{value:,}', ha='center', va='bottom')
plt.show()

# %%
fig = px.pie(values = ev_type_counts.values, names=ev_type_counts.index ,title='Distribution of Electric Vehicle Type')
fig.show()

# %% [markdown]
# # 6. What is the trend of EV sales over the years?

# %%
model_year_counts = df['Model Year'].value_counts()
print(model_year_counts)
print(model_year_counts.values)
print(model_year_counts.index)
# Out:
# Model Year
# 2023    37365
# 2022    21101
# 2024    15990
# 2021    14413
# 2018    10536
# 2020     9912
# 2019     8866
# 2017     7605
# 2016     5077
# 2015     4002
# 2013     3664
# 2014     3314
# 2012     1486
# 2011      631
# 2025       48
# 2010       24
# 2008       21
# 2000        7
# 1999        5
# 2002        2
# 1997        1
# 2003        1
# Name: count, dtype: int64
# [37365 21101 15990 14413 10536  9912  8866  7605  5077  4002  3664  3314
#   1486   631    48    24    21     7     5     2     1     1]
# Index([2023, 2022, 2024, 2021, 2018, 2020, 2019, 2017, 2016, 2015, 2013, 2014,
#        2012, 2011, 2025, 2010, 2008, 2000, 1999, 2002, 1997, 2003],
#       dtype='int64', name='Model Year')

# %%
plt.figure(figsize= (12,6))
sns.lineplot( x = model_year_counts.index , y =model_year_counts.values  ,marker= 'o')
plt.title("Trend of Electric Vehicle (EV) Sales Over the Years")
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles')
plt.grid('True' ,linestyle ='--', alpha=0.7 )
plt.xticks(rotation = 45)

#incrase the number of interval on y axis
max_value = df['Model Year'].value_counts().max()
plt.ylim(0, max_value *1.2)

# Increase the number of intervals on the x-axis
plt.xticks(ticks=np.arange(model_year_counts.index.min(), model_year_counts.index.max() + 1, 1))

# Annotate each point with the exact count
for index, value in enumerate(model_year_counts.values):
    plt.text(model_year_counts.index[index], value, f'{value:,}', ha='center', va='bottom' ,rotation=90)

# Show the plot
plt.show()
# 'top', 'bottom', 'center', 'baseline', 'center_baseline'

# %% [markdown]
# # 7. What is the count and percentage distribution of Clean Alternative Fuel Vehicles (CAFVs)?

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
cafv_counts = df ['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
print(cafv_counts)
print(cafv_counts.index)
print(cafv_counts.values)
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Eligibility unknown as battery range has not been researched    69873
# Clean Alternative Fuel Vehicle Eligible                         55527
# Not eligible due to low battery range                           18671
# Name: count, dtype: int64
# Index(['Eligibility unknown as battery range has not been researched',
#        'Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range'],
#       dtype='object', name='Clean Alternative Fuel Vehicle (CAFV) Eligibility')
# [69873 55527 18671]

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=cafv_counts.index, y=cafv_counts.values)
plt.title('"Distribution of Clean Alternative Fuel Vehicles (CAFVs)"')
plt.xlabel('CAFV Eligibility')
plt.ylabel('Count')
plt.xticks(rotation =45)
# Display the count above each bar
for index, values in enumerate(cafv_counts.values):
    plt.text(index, values, f'{values:,}' , ha='center' ,va='bottom')
# Increase the range of the y-axis to add some space above the highest bar
plt.ylim(0, cafv_counts.max() * 1.2)
plt.show()

# %%
fig1 = px.pie(values = cafv_counts.values , names=cafv_counts.index, title='"Distribution of Clean Alternative Fuel Vehicles (CAFVs)"' )
fig1.show()

# %% [markdown]
# # 8. What is the average range of different makes?

# %%
average_range_by_make =  df.groupby('Make')['Electric Range'].mean().sort_values(ascending = False)
print(average_range_by_make)
# Out:
# Make
# JAGUAR                  204.623377
# WHEEGO ELECTRIC CARS    100.000000
# TH!NK                   100.000000
# CHEVROLET                93.279147
# TESLA                    90.901582
# FIAT                     85.041555
# NISSAN                   75.561695
# SMART                    62.132812
# AZURE DYNAMICS           56.000000
# AUDI                     46.051769
# HONDA                    44.477381
# PORSCHE                  43.986395
# KIA                      41.544768
# POLESTAR                 35.806806
# BMW                      33.515510
# ALFA ROMEO               33.000000
# CHRYSLER                 32.250304
# DODGE                    32.000000
# MITSUBISHI               31.206221
# LAND ROVER               28.142857
# TOYOTA                   27.823051
# MAZDA                    25.694631
# LINCOLN                  23.643357
# JEEP                     22.417248
# BENTLEY                  21.750000
# VOLKSWAGEN               21.153458
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x= average_range_by_make.index , y=average_range_by_make.values ) 
plt.title('"Average Range of Different EV Makes"')
plt.xlabel('Make')
plt.ylabel('Average Electric Range (miles)')
plt.xticks(rotation =80)
plt.grid(axis ='y' , linestyle ='--'  , alpha=0.7)
# Increase the range of the y-axis to add some space above the highest bar
max_average_range_by_make = average_range_by_make.max()
y_ticks = np.linspace(0, max_average_range_by_make *1.1 ,20)
y_ticks_int = np.round(y_ticks).astype(int)  # Convert to integer
plt.yticks(y_ticks_int)
# Display the count above each line
for index, value in enumerate(np.round(average_range_by_make.values,2)):
    plt.text(index , value, f'{value:,}', ha='center', va='bottom' ,rotation = 80)
plt.show()

# %%
average_range_by_make =  df.groupby('Make')['Electric Range'].mean().nlargest(10)
fig1 = px.pie(values = average_range_by_make.values , names=average_range_by_make.index, title="Top 10 EV Makes by Average Range (Percentage)" )
fig1.show()

# %% [markdown]
# # 9. what are the top 10 makes by average range in percentage?

# %%
average_range_by_make =  df.groupby('Make')['Electric Range'].mean().nlargest(10)
fig1 = px.pie(values = average_range_by_make.values , names=average_range_by_make.index, title='Top 10 Make Average Range' )
fig1.show()

# %% [markdown]
# # 10. what are the top 10 makes by average range?

# %%
# Step 1: Get the top 10 makes by their count
top_10_make = df['Make'].value_counts().nlargest(10)

# Step 2: Filter the DataFrame to include only the top 10 makes
top_10_make_df = df[df["Make"].isin(top_10_make.index)]

# Step 3: Calculate the average electric range for each of the top 10 makes and sort in descending order
average_range_by_top_10_make = top_10_make_df.groupby('Make')['Electric Range'].mean().sort_values(ascending=False)

# %%
# Step 1: Get the top 10 makes by their count
top_10_make = df['Make'].value_counts().nlargest(10)

# Step 2: Filter the DataFrame to include only the top 10 makes
top_10_make_df = df[df["Make"].isin(top_10_make.index)]

# Step 3: Calculate the average electric range for each of the top 10 makes and sort in descending order
average_range_by_top_10_make = top_10_make_df.groupby('Make')['Electric Range'].mean().sort_values(ascending=False)

# Display the result
plt.figure(figsize=(10,6))
sns.barplot(x=average_range_by_top_10_make.index, y=average_range_by_top_10_make.values)
# Increase the range of the y-axis to add some space above the highest bar
max1 = average_range_by_top_10_make.max()
plt.ylim(0, max1 *1.1)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # 11. Which are the top 10 makes with the highest number of vehicles  in the top 10 counties?

# %%
# 1. Get the top 10 counties by occurrence
Top_10_county = df['County'].value_counts().nlargest(10)
# 2. Filter the DataFrame to include only the rows where County is in the top 10
top_10_county_df = df[df['County'].isin(Top_10_county.index)]
# 3. Get the top 10 Model by occurrence
top_10_make_df  = top_10_county_df['Make'].value_counts().nlargest(10)
# 4. Filter the DataFrame to include only the rows where Model is in the top 10
top_10_county_df = top_10_county_df[top_10_county_df['Make'].isin(top_10_make_df.index)]
top_10_county_df['count1'] =1

pivot_table = top_10_county_df.pivot_table(
    index='Make',
    columns='County',
    aggfunc='size'
)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True , fmt='d' ,cmap='YlGnBu')
plt.title('Top 10 Car Manufacturer in Top 10 Counties')
plt.xlabel('County')
plt.ylabel('Car Maker')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)
plt.show()

# %%
pivot_table = top_10_county_df.pivot_table(
    index='County',
    columns='Make',
    aggfunc='size'
)
pivot_table
pivot_table.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='County'>

# %% [markdown]
# # 12. Which are the top 10 models with the highest number of vehicles  in the top 10 counties?

# %%
# 1. Get the top 10 counties by occurrence
Top_10_county = df['County'].value_counts().nlargest(10)
# 2. Filter the DataFrame to include only the rows where County is in the top 10
top_10_county_df = df[df['County'].isin(Top_10_county.index)]
# 3. Get the top 10 Model by occurrence
top_10_model_df  = top_10_county_df['Model'].value_counts().nlargest(10)
# 4. Filter the DataFrame to include only the rows where Model is in the top 10
top_10_county_df = top_10_county_df[top_10_county_df['Model'].isin(top_10_model_df.index)]
top_10_county_df['count1'] =1

pivot_table = top_10_county_df.pivot_table(
    index='Model',
    columns='County',
    aggfunc='size'
)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True , fmt='d' ,cmap='YlGnBu')
plt.title('Top 10 Car Models in Top 10 Counties')
plt.xlabel('County')
plt.ylabel('Car Model')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # 13. Which are the top 10 makes with the highest number of vehicles  in the top 10 cities?

# %%
# 1. Get the top 10 counties by occurrence
Top_10_city = df['City'].value_counts().nlargest(10)
# 2. Filter the DataFrame to include only the rows where County is in the top 10
top_10_city_df = df[df['City'].isin(Top_10_city.index)]
# 3. Get the top 10 Model by occurrence
top_10_make_df  = top_10_city_df['Make'].value_counts().nlargest(10)
# 4. Filter the DataFrame to include only the rows where Model is in the top 10
top_10_city_df = top_10_city_df[top_10_city_df['Make'].isin(top_10_make_df.index)]
top_10_city_df['count1'] =1

pivot_table = top_10_city_df.pivot_table(
    index='Make',
    columns='City',
    aggfunc='size'
)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True , fmt='d' ,cmap='YlGnBu')
plt.title('Top 10 Car Manufacturer in Top 10 Cities')
plt.xlabel('City')
plt.ylabel('Car Maker')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # 14. Which are the top 10 models with the highest number of vehicles  in the top 10 cities?

# %%
# 1. Get the top 10 counties by occurrence
Top_10_city = df['City'].value_counts().nlargest(10)
# 2. Filter the DataFrame to include only the rows where County is in the top 10
top_10_city_df = df[df['City'].isin(Top_10_city.index)]
# 3. Get the top 10 Model by occurrence
top_10_make_df  = top_10_city_df['Model'].value_counts().nlargest(10)
# 4. Filter the DataFrame to include only the rows where Model is in the top 10
top_10_city_df = top_10_city_df[top_10_city_df['Model'].isin(top_10_make_df.index)]
top_10_city_df['count1'] =1

pivot_table = top_10_city_df.pivot_table(
    index='Model',
    columns='City',
    aggfunc='size'
)
pivot_table
# Out:
# City            Bellevue  Bothell  Kirkland  Olympia  Redmond  Renton  \
# Model
# BOLT EV              111       90        97      202       81      73
# ID.4                  98       89        97      151       96      78
# LEAF                 379      277       205      299      239     226
# MODEL 3              700      412       321      384      333     463
# MODEL S              415      178       219      156      221     154
# MODEL X              438      210       213      107      263     172
# MODEL Y              682      433       302      364      332     486
# MUSTANG MACH-E        96      107        63      116      104      92
# NIRO                  79       64        62      128       62     120
# VOLT                  84       81        70      164       78     100
#
# City            Sammamish  Seattle  Tacoma  Vancouver
# Model
# BOLT EV                57     1019     145        210
# ID.4                   74      831      95        150
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True , fmt='d' ,cmap='YlGnBu')
plt.title('Top 10 Car Model in Top 10 Cities')
plt.xlabel('City')
plt.ylabel('Car Model')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # 15. What are the top models of the top 1 make by count?

# %%
Tesla = df['Make'].value_counts().nlargest(1) 
Tesla = df[ df['Make'].isin(Tesla.index) ]
Tesla_models = Tesla['Model'].value_counts()
# Increase the range of the y-axis to add some space above the highest bar
max1= Tesla_models.max()
plt.figure(figsize=(10,6))
sns.barplot(x=Tesla_models.index , y=Tesla_models.values)
plt.title('Top Models of the Leading EV Make by count')
# plt.grid(True)
plt.grid(axis ='y' , linestyle='--', alpha=0.7)
plt.ylim(0, max1 * 1.1 )
# Display the count above each bar
for index, value in enumerate(Tesla_models.values):
    plt.text(index, value, f'{value:,}' , ha='center' , va='bottom')

# %% [markdown]
# # 16. Tesla Models Electric Range

# %%
average_range_tesla_model = Tesla.groupby('Model')['Electric Range'].mean()
plt.figure(figsize=(10,6))
sns.barplot(x=average_range_tesla_model.index , y=average_range_tesla_model.values)
plt.title('Average Range of Tesla Models')
plt.show()
